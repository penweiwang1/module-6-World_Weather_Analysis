# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | namtsy
# Processing Record 3 of Set 1 | big spring
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | leningradskiy
# Processing Record 7 of Set 1 | olga
# Processing Record 8 of Set 1 | port hardy
# Processing Record 9 of Set 1 | kavaratti
# Processing Record 10 of Set 1 | camacha
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | arona
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | torbay
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | marawi
# Processing Record 18 of Set 1 | jibuti
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | abnub
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | nazilli
# Processing Record 26 of Set 1 | prince rupert
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | markova
# Processing Record 32 of Set 1 | reconquista
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | kimbe
# Processing Record 35 of Set 1 | mahebourg
# Processing Record 36 of Set 1 | kirakira
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | yerofey pavlovich
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | salalah
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | chacabuco
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | usinsk
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | sri aman
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | yerbogachen
# Processing Record 3 of Set 2 | carutapera
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | manadhoo
# Processing Record 9 of Set 2 | volodarka
# Processing Record 10 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 2 | meulaboh
# Processing Record 12 of Set 2 | fairbanks
# Processing Record 13 of Set 2 | trinidad
# Processing Record 14 of Set 2 | teguldet
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | deputatskiy
# Processing Record 20 of Set 2 | santa fe
# Processing Record 21 of Set 2 | bathsheba
# Processing Record 22 of Set 2 | biak
# Processing Record 23 of Set 2 | saint-pierre
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | san miguel
# Processing Record 26 of Set 2 | havelock
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | roald
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | nurota
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | sao manuel
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | jaque
# Processing Record 39 of Set 2 | margate
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | bani walid
# Processing Record 43 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 2 | havoysund
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 2 | wasilla
# Processing Record 49 of Set 2 | katherine
# Processing Record 50 of Set 2 | ciudad bolivar
# Processing Record 1 of Set 3 | kieta
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | lamar
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | swan river
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | diffa
# Processing Record 9 of Set 3 | masallatah
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | north bend
# Processing Record 15 of Set 3 | hongjiang
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | plettenberg bay
# Processing Record 18 of Set 3 | henderson
# Processing Record 19 of Set 3 | shieli
# Processing Record 20 of Set 3 | nizhniy kuranakh
# Processing Record 21 of Set 3 | kyren
# Processing Record 22 of Set 3 | de-kastri
# Processing Record 23 of Set 3 | alta floresta
# Processing Record 24 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 25 of Set 3 | kenai
# Processing Record 26 of Set 3 | caconda
# Processing Record 27 of Set 3 | cine
# Processing Record 28 of Set 3 | namibe
# Processing Record 29 of Set 3 | memmingen
# Processing Record 30 of Set 3 | mopipi
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | katobu
# Processing Record 33 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | lata
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | poronaysk
# Processing Record 37 of Set 3 | esperance
# Processing Record 38 of Set 3 | namatanai
# Processing Record 39 of Set 3 | barra do bugres
# Processing Record 40 of Set 3 | abu dhabi
# Processing Record 41 of Set 3 | qabis
# City not found. Skipping...
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | terrace
# Processing Record 44 of Set 3 | bartica
# Processing Record 45 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | terney
# Processing Record 48 of Set 3 | kaputa
# Processing Record 49 of Set 3 | luanda
# Processing Record 50 of Set 3 | tuatapere
# Processing Record 1 of Set 4 | kurakh
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 4 | lorengau
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | sechura
# Processing Record 9 of Set 4 | metro
# Processing Record 10 of Set 4 | moerai
# Processing Record 11 of Set 4 | la rioja
# Processing Record 12 of Set 4 | comodoro rivadavia
# Processing Record 13 of Set 4 | mopti
# Processing Record 14 of Set 4 | navalcarnero
# Processing Record 15 of Set 4 | gobabis
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | charters towers
# Processing Record 18 of Set 4 | kargasok
# Processing Record 19 of Set 4 | sunbury
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | mbour
# Processing Record 22 of Set 4 | port augusta
# Processing Record 23 of Set 4 | araouane
# Processing Record 24 of Set 4 | iralaya
# Processing Record 25 of Set 4 | mitsuke
# Processing Record 26 of Set 4 | horki
# Processing Record 27 of Set 4 | atasu
# Processing Record 28 of Set 4 | kanata
# Processing Record 29 of Set 4 | busselton
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | aitape
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | aleksandrov gay
# Processing Record 34 of Set 4 | san cristobal
# Processing Record 35 of Set 4 | half moon bay
# Processing Record 36 of Set 4 | luganville
# Processing Record 37 of Set 4 | tuim
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | kupang
# Processing Record 40 of Set 4 | tumut
# Processing Record 41 of Set 4 | boffa
# Processing Record 42 of Set 4 | bardiyah
# Processing Record 43 of Set 4 | moron
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | avondale
# Processing Record 46 of Set 4 | ivanava
# Processing Record 47 of Set 4 | gurmatkal
# Processing Record 48 of Set 4 | pocone
# Processing Record 49 of Set 4 | guerrero negro
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | huarmey
# Processing Record 4 of Set 5 | chipinge
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | champerico
# Processing Record 7 of Set 5 | behshahr
# Processing Record 8 of Set 5 | jumla
# Processing Record 9 of Set 5 | basoko
# Processing Record 10 of Set 5 | whitehorse
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | dikson
# Processing Record 13 of Set 5 | sawtell
# Processing Record 14 of Set 5 | evensk
# Processing Record 15 of Set 5 | ypsonas
# Processing Record 16 of Set 5 | gizo
# Processing Record 17 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | blackwater
# Processing Record 19 of Set 5 | severo-kurilsk
# Processing Record 20 of Set 5 | barinitas
# Processing Record 21 of Set 5 | preobrazheniye
# Processing Record 22 of Set 5 | pinega
# Processing Record 23 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 5 | graham
# Processing Record 25 of Set 5 | merauke
# Processing Record 26 of Set 5 | baykit
# Processing Record 27 of Set 5 | naryan-mar
# Processing Record 28 of Set 5 | mayya
# Processing Record 29 of Set 5 | landskrona
# Processing Record 30 of Set 5 | muzhi
# Processing Record 31 of Set 5 | albany
# Processing Record 32 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 5 | vinh
# Processing Record 34 of Set 5 | nakhon phanom
# Processing Record 35 of Set 5 | saint-georges
# Processing Record 36 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 5 | sioux lookout
# Processing Record 38 of Set 5 | baruun-urt
# Processing Record 39 of Set 5 | bilibino
# Processing Record 40 of Set 5 | duz
# City not found. Skipping...
# Processing Record 41 of Set 5 | kondagaon
# Processing Record 42 of Set 5 | belaya gora
# Processing Record 43 of Set 5 | arcachon
# Processing Record 44 of Set 5 | pointe michel
# Processing Record 45 of Set 5 | odweyne
# Processing Record 46 of Set 5 | yomou
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | san policarpo
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | cidreira
# Processing Record 1 of Set 6 | erdenet
# Processing Record 2 of Set 6 | yei
# Processing Record 3 of Set 6 | pinheiral
# Processing Record 4 of Set 6 | sept-iles
# Processing Record 5 of Set 6 | saint-louis
# Processing Record 6 of Set 6 | new glasgow
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | aneho
# Processing Record 9 of Set 6 | carnarvon
# Processing Record 10 of Set 6 | hauterive
# Processing Record 11 of Set 6 | racale
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | loja
# Processing Record 14 of Set 6 | hays
# Processing Record 15 of Set 6 | vestmannaeyjar
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | qaanaaq
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | vodnyy
# Processing Record 21 of Set 6 | kisangani
# Processing Record 22 of Set 6 | sinnamary
# Processing Record 23 of Set 6 | avarua
# Processing Record 24 of Set 6 | lokosovo
# Processing Record 25 of Set 6 | tevriz
# Processing Record 26 of Set 6 | aktau
# Processing Record 27 of Set 6 | svobodnyy
# Processing Record 28 of Set 6 | sola
# Processing Record 29 of Set 6 | mastic beach
# Processing Record 30 of Set 6 | korla
# Processing Record 31 of Set 6 | dunyapur
# Processing Record 32 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 6 | varhaug
# Processing Record 34 of Set 6 | lompoc
# Processing Record 35 of Set 6 | imeni poliny osipenko
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | tyret pervaya
# Processing Record 38 of Set 6 | hami
# Processing Record 39 of Set 6 | kamaishi
# Processing Record 40 of Set 6 | san rafael
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | la palma
# Processing Record 43 of Set 6 | ambalavao
# Processing Record 44 of Set 6 | vila franca do campo
# Processing Record 45 of Set 6 | moorhead
# Processing Record 46 of Set 6 | montego bay
# Processing Record 47 of Set 6 | mahajanga
# Processing Record 48 of Set 6 | port macquarie
# Processing Record 49 of Set 6 | yangambi
# Processing Record 50 of Set 6 | tomohon
# Processing Record 1 of Set 7 | oktyabrskoye
# Processing Record 2 of Set 7 | nuuk
# Processing Record 3 of Set 7 | stornoway
# Processing Record 4 of Set 7 | quang ngai
# Processing Record 5 of Set 7 | severo-yeniseyskiy
# Processing Record 6 of Set 7 | roma
# Processing Record 7 of Set 7 | wenling
# Processing Record 8 of Set 7 | hokitika
# Processing Record 9 of Set 7 | cabedelo
# Processing Record 10 of Set 7 | memari
# Processing Record 11 of Set 7 | hervey bay
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | rafai
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | scottsbluff
# Processing Record 16 of Set 7 | seuzach
# Processing Record 17 of Set 7 | coihaique
# Processing Record 18 of Set 7 | maun
# Processing Record 19 of Set 7 | dakar
# Processing Record 20 of Set 7 | catamarca
# Processing Record 21 of Set 7 | trairi
# Processing Record 22 of Set 7 | chokurdakh
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | upernavik
# Processing Record 25 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 7 | zyryanovsk
# Processing Record 28 of Set 7 | melito di porto salvo
# Processing Record 29 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 7 | onega
# Processing Record 31 of Set 7 | longyearbyen
# Processing Record 32 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | praia
# Processing Record 35 of Set 7 | lasa
# Processing Record 36 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 7 | asau
# Processing Record 38 of Set 7 | ban nahin
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | briancon
# Processing Record 41 of Set 7 | vao
# Processing Record 42 of Set 7 | mahon
# Processing Record 43 of Set 7 | mumford
# Processing Record 44 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | beyneu
# Processing Record 47 of Set 7 | ribeira grande
# Processing Record 48 of Set 7 | redcliffe
# Processing Record 49 of Set 7 | zhangye
# Processing Record 50 of Set 7 | camp verde
# Processing Record 1 of Set 8 | barberton
# Processing Record 2 of Set 8 | mosquera
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | hamilton
# Processing Record 5 of Set 8 | ust-tsilma
# Processing Record 6 of Set 8 | kismayo
# Processing Record 7 of Set 8 | coahuayana
# Processing Record 8 of Set 8 | nagpur
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | pyay
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | karratha
# Processing Record 13 of Set 8 | hojai
# Processing Record 14 of Set 8 | ca mau
# Processing Record 15 of Set 8 | jamame
# Processing Record 16 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 8 | wattegama
# Processing Record 18 of Set 8 | san patricio
# Processing Record 19 of Set 8 | shimoda
# Processing Record 20 of Set 8 | koumac
# Processing Record 21 of Set 8 | marquette
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | mallaig
# Processing Record 24 of Set 8 | tucurui
# Processing Record 25 of Set 8 | rawson
# Processing Record 26 of Set 8 | beringovskiy
# Processing Record 27 of Set 8 | sibolga
# Processing Record 28 of Set 8 | ikauna
# Processing Record 29 of Set 8 | belturbet
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | zhumadian
# Processing Record 32 of Set 8 | terenga
# City not found. Skipping...
# Processing Record 33 of Set 8 | saldanha
# Processing Record 34 of Set 8 | atkinson
# Processing Record 35 of Set 8 | kulunda
# Processing Record 36 of Set 8 | jiuquan
# Processing Record 37 of Set 8 | slave lake
# Processing Record 38 of Set 8 | yelkhovka
# Processing Record 39 of Set 8 | college
# Processing Record 40 of Set 8 | ojinaga
# Processing Record 41 of Set 8 | arrifes
# Processing Record 42 of Set 8 | matehuala
# Processing Record 43 of Set 8 | george
# Processing Record 44 of Set 8 | avera
# Processing Record 45 of Set 8 | sawakin
# Processing Record 46 of Set 8 | airai
# Processing Record 47 of Set 8 | loandjili
# Processing Record 48 of Set 8 | pingdingshan
# Processing Record 49 of Set 8 | olafsvik
# Processing Record 50 of Set 8 | berezovyy
# Processing Record 1 of Set 9 | farafangana
# Processing Record 2 of Set 9 | kuantan
# Processing Record 3 of Set 9 | barcelona
# Processing Record 4 of Set 9 | suleja
# Processing Record 5 of Set 9 | grindavik
# Processing Record 6 of Set 9 | sur
# Processing Record 7 of Set 9 | taoudenni
# Processing Record 8 of Set 9 | sao jose da coroa grande
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | kamsack
# Processing Record 11 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 9 | coquimbo
# Processing Record 13 of Set 9 | bantou
# Processing Record 14 of Set 9 | santa isabel do rio negro
# Processing Record 15 of Set 9 | xichang
# Processing Record 16 of Set 9 | kindu
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | fare
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | mahibadhoo
# Processing Record 21 of Set 9 | viedma
# Processing Record 22 of Set 9 | xiongzhou
# Processing Record 23 of Set 9 | fukue
# Processing Record 24 of Set 9 | bograd
# Processing Record 25 of Set 9 | teguise
# Processing Record 26 of Set 9 | raska
# Processing Record 27 of Set 9 | bo phloi
# Processing Record 28 of Set 9 | roebourne
# Processing Record 29 of Set 9 | berdigestyakh
# Processing Record 30 of Set 9 | najran
# Processing Record 31 of Set 9 | thompson
# Processing Record 32 of Set 9 | panjab
# Processing Record 33 of Set 9 | port elizabeth
# Processing Record 34 of Set 9 | parana
# Processing Record 35 of Set 9 | george town
# Processing Record 36 of Set 9 | khatra
# Processing Record 37 of Set 9 | bonthe
# Processing Record 38 of Set 9 | kashi
# Processing Record 39 of Set 9 | luangwa
# Processing Record 40 of Set 9 | matara
# Processing Record 41 of Set 9 | langenhagen
# Processing Record 42 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 9 | bubaque
# Processing Record 44 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 9 | lahaina
# Processing Record 46 of Set 9 | ngunguru
# Processing Record 47 of Set 9 | baherden
# Processing Record 48 of Set 9 | christchurch
# Processing Record 49 of Set 9 | manokwari
# Processing Record 50 of Set 9 | mantua
# Processing Record 1 of Set 10 | ha
# City not found. Skipping...
# Processing Record 2 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 10 | hermsdorf
# Processing Record 4 of Set 10 | flin flon
# Processing Record 5 of Set 10 | marystown
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | seoul
# Processing Record 8 of Set 10 | srivardhan
# Processing Record 9 of Set 10 | sangar
# Processing Record 10 of Set 10 | alice springs
# Processing Record 11 of Set 10 | chimbarongo
# Processing Record 12 of Set 10 | tazovskiy
# Processing Record 13 of Set 10 | heinola
# Processing Record 14 of Set 10 | port blair
# Processing Record 15 of Set 10 | kununurra
# Processing Record 16 of Set 10 | verkhnyaya inta
# Processing Record 17 of Set 10 | cabo san lucas
# Processing Record 18 of Set 10 | dapdap
# Processing Record 19 of Set 10 | saundatti yellamma
# City not found. Skipping...
# Processing Record 20 of Set 10 | magan
# Processing Record 21 of Set 10 | yauya
# Processing Record 22 of Set 10 | semey
# Processing Record 23 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 24 of Set 10 | norman wells
# Processing Record 25 of Set 10 | tagusao
# Processing Record 26 of Set 10 | chunoyar
# Processing Record 27 of Set 10 | balkhash
# Processing Record 28 of Set 10 | novopavlovka
# Processing Record 29 of Set 10 | lewisporte
# Processing Record 30 of Set 10 | dhidhdhoo
# Processing Record 31 of Set 10 | shelburne
# Processing Record 32 of Set 10 | pochutla
# Processing Record 33 of Set 10 | rocha
# Processing Record 34 of Set 10 | panhala
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 10 | portland
# Processing Record 38 of Set 10 | dabwali
# Processing Record 39 of Set 10 | buta
# Processing Record 40 of Set 10 | milkovo
# Processing Record 41 of Set 10 | touros
# Processing Record 42 of Set 10 | seddon
# Processing Record 43 of Set 10 | provideniya
# Processing Record 44 of Set 10 | andra
# Processing Record 45 of Set 10 | kesova gora
# Processing Record 46 of Set 10 | dunmore east
# Processing Record 47 of Set 10 | yuancheng
# Processing Record 48 of Set 10 | garissa
# Processing Record 49 of Set 10 | vaitape
# Processing Record 50 of Set 10 | morondava
# Processing Record 1 of Set 11 | laguna
# Processing Record 2 of Set 11 | tanout
# Processing Record 3 of Set 11 | bonavista
# Processing Record 4 of Set 11 | samana
# Processing Record 5 of Set 11 | nyurba
# Processing Record 6 of Set 11 | coari
# Processing Record 7 of Set 11 | cap-aux-meules
# Processing Record 8 of Set 11 | tautira
# Processing Record 9 of Set 11 | oxapampa
# Processing Record 10 of Set 11 | beaverlodge
# Processing Record 11 of Set 11 | humaita
# Processing Record 12 of Set 11 | nhulunbuy
# Processing Record 13 of Set 11 | adeje
# Processing Record 14 of Set 11 | barentu
# Processing Record 15 of Set 11 | burnie
# Processing Record 16 of Set 11 | aykhal
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | santa vitoria do palmar
# Processing Record 19 of Set 11 | zabol
# Processing Record 20 of Set 11 | khani
# Processing Record 21 of Set 11 | canberra
# Processing Record 22 of Set 11 | coolum beach
# Processing Record 23 of Set 11 | soltsy
# Processing Record 24 of Set 11 | dwarka
# Processing Record 25 of Set 11 | ler
# Processing Record 26 of Set 11 | terrace bay
# Processing Record 27 of Set 11 | never
# Processing Record 28 of Set 11 | rio gallegos
# Processing Record 29 of Set 11 | wakkanai
# Processing Record 30 of Set 11 | great yarmouth
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | ribas do rio pardo
# Processing Record 33 of Set 11 | vanimo
# Processing Record 34 of Set 11 | ayan
# Processing Record 35 of Set 11 | palmer
# Processing Record 36 of Set 11 | san jeronimo
# Processing Record 37 of Set 11 | okhotsk
# Processing Record 38 of Set 11 | popondetta
# Processing Record 39 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 11 | fort nelson
# Processing Record 41 of Set 11 | riyadh
# Processing Record 42 of Set 11 | imbituba
# Processing Record 43 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 11 | bowen
# Processing Record 45 of Set 11 | san pedro
# Processing Record 46 of Set 11 | gazimurskiy zavod
# Processing Record 47 of Set 11 | digha
# Processing Record 48 of Set 11 | larsnes
# Processing Record 49 of Set 11 | puerto quijarro
# Processing Record 50 of Set 11 | kidal
# Processing Record 1 of Set 12 | cantapoy
# Processing Record 2 of Set 12 | punta de bombon
# Processing Record 3 of Set 12 | riviere-au-renard
# Processing Record 4 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 12 | capandanan
# Processing Record 6 of Set 12 | celestun
# Processing Record 7 of Set 12 | hovd
# Processing Record 8 of Set 12 | kalmunai
# Processing Record 9 of Set 12 | baglung
# Processing Record 10 of Set 12 | nanao
# Processing Record 11 of Set 12 | olinda
# Processing Record 12 of Set 12 | mamou
# Processing Record 13 of Set 12 | tual
# Processing Record 14 of Set 12 | cremona
# Processing Record 15 of Set 12 | dickson
# Processing Record 16 of Set 12 | alyangula
# Processing Record 17 of Set 12 | holme
# Processing Record 18 of Set 12 | tire
# Processing Record 19 of Set 12 | shingu
# Processing Record 20 of Set 12 | rey bouba
# Processing Record 21 of Set 12 | arlit
# Processing Record 22 of Set 12 | manjacaze
# Processing Record 23 of Set 12 | zinder
# Processing Record 24 of Set 12 | darhan
# Processing Record 25 of Set 12 | edson
# Processing Record 26 of Set 12 | ilebo
# Processing Record 27 of Set 12 | jha jha
# Processing Record 28 of Set 12 | malaut
# Processing Record 29 of Set 12 | pokhara
# Processing Record 30 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 31 of Set 12 | saint-joseph
# Processing Record 32 of Set 12 | buala
# Processing Record 33 of Set 12 | garowe
# Processing Record 34 of Set 12 | sao joao da barra
# Processing Record 35 of Set 12 | liepaja
# Processing Record 36 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 12 | zelenets
# Processing Record 38 of Set 12 | anadyr
# Processing Record 39 of Set 12 | buluang
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | mezdra
# Processing Record 42 of Set 12 | joao pinheiro
# Processing Record 43 of Set 12 | santo domingo
# Processing Record 44 of Set 12 | necochea
# Processing Record 45 of Set 12 | neepawa
# Processing Record 46 of Set 12 | okha
# Processing Record 47 of Set 12 | san lorenzo de el escorial
# Processing Record 48 of Set 12 | acarau
# Processing Record 49 of Set 12 | mecca
# Processing Record 50 of Set 12 | campbell river
# Processing Record 1 of Set 13 | albertville
# Processing Record 2 of Set 13 | brae
# Processing Record 3 of Set 13 | zhigansk
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | narsaq
# Processing Record 6 of Set 13 | alindao
# Processing Record 7 of Set 13 | boa vista
# Processing Record 8 of Set 13 | chicama
# Processing Record 9 of Set 13 | yanam
# Processing Record 10 of Set 13 | novyy urengoy
# Processing Record 11 of Set 13 | khandbari
# Processing Record 12 of Set 13 | sainte-thecle
# Processing Record 13 of Set 13 | skibbereen
# Processing Record 14 of Set 13 | pimentel
# Processing Record 15 of Set 13 | kuah
# Processing Record 16 of Set 13 | ontario
# Processing Record 17 of Set 13 | krynychky
# Processing Record 18 of Set 13 | yibin
# Processing Record 19 of Set 13 | manavalakurichi
# Processing Record 20 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 21 of Set 13 | sulangan
# Processing Record 22 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 23 of Set 13 | te anau
# Processing Record 24 of Set 13 | samfya
# Processing Record 25 of Set 13 | krsko
# Processing Record 26 of Set 13 | leh
# Processing Record 27 of Set 13 | velke hamry
# Processing Record 28 of Set 13 | lubumbashi
# Processing Record 29 of Set 13 | west plains
# Processing Record 30 of Set 13 | buraydah
# Processing Record 31 of Set 13 | beziers
# Processing Record 32 of Set 13 | kilindoni
# Processing Record 33 of Set 13 | techiman
# Processing Record 34 of Set 13 | itaituba
# Processing Record 35 of Set 13 | acajutla
# Processing Record 36 of Set 13 | valparaiso
# Processing Record 37 of Set 13 | williston
# Processing Record 38 of Set 13 | oranjemund
# Processing Record 39 of Set 13 | mtsamboro
# Processing Record 40 of Set 13 | oyama
# Processing Record 41 of Set 13 | longyan
# Processing Record 42 of Set 13 | takoradi
# Processing Record 43 of Set 13 | gander
# Processing Record 44 of Set 13 | mitu
# Processing Record 45 of Set 13 | lagos
# Processing Record 46 of Set 13 | pundaguitan
# Processing Record 47 of Set 13 | yumen
# Processing Record 48 of Set 13 | orasac
# Processing Record 49 of Set 13 | grootfontein
# Processing Record 50 of Set 13 | grand gaube
# Processing Record 1 of Set 14 | tezu
# Processing Record 2 of Set 14 | gorontalo
# Processing Record 3 of Set 14 | alcala la real
# Processing Record 4 of Set 14 | aasiaat
# Processing Record 5 of Set 14 | bodden town
# Processing Record 6 of Set 14 | myrtle beach
# Processing Record 7 of Set 14 | umm lajj
# Processing Record 8 of Set 14 | labuhan
# Processing Record 9 of Set 14 | multan
# Processing Record 10 of Set 14 | nanhai
# Processing Record 11 of Set 14 | severnyy
# Processing Record 12 of Set 14 | kodinsk
# Processing Record 13 of Set 14 | sayyan
# Processing Record 14 of Set 14 | acapulco
# Processing Record 15 of Set 14 | inuvik
# Processing Record 16 of Set 14 | zapolyarnyy
# Processing Record 17 of Set 14 | chaves
# Processing Record 18 of Set 14 | ritchie
# Processing Record 19 of Set 14 | inhambane
# Processing Record 20 of Set 14 | bima
# Processing Record 21 of Set 14 | oblivskaya
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | paamiut
# Processing Record 24 of Set 14 | bluefield
# Processing Record 25 of Set 14 | alofi
# Processing Record 26 of Set 14 | natal
# Processing Record 27 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 14 | wanning
# Processing Record 29 of Set 14 | mansa
# Processing Record 30 of Set 14 | fuling
# Processing Record 31 of Set 14 | gemena
# Processing Record 32 of Set 14 | batagay
# Processing Record 33 of Set 14 | syracuse
# Processing Record 34 of Set 14 | tignere
# Processing Record 35 of Set 14 | slovenska bistrica
# Processing Record 36 of Set 14 | hobyo
# Processing Record 37 of Set 14 | fasa
# Processing Record 38 of Set 14 | mayo
# Processing Record 39 of Set 14 | gisborne
# Processing Record 40 of Set 14 | kurilsk
# Processing Record 41 of Set 14 | byron bay
# Processing Record 42 of Set 14 | copiapo
# Processing Record 43 of Set 14 | olgod
# Processing Record 44 of Set 14 | altay
# Processing Record 45 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 14 | pervomayskoye
# Processing Record 47 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 14 | birao
# Processing Record 49 of Set 14 | teya
# Processing Record 50 of Set 14 | pagsangahan
# Processing Record 1 of Set 15 | kyabe
# Processing Record 2 of Set 15 | ternate
# Processing Record 3 of Set 15 | chhagalnaiya
# Processing Record 4 of Set 15 | jacareacanga
# Processing Record 5 of Set 15 | kletskaya
# Processing Record 6 of Set 15 | los llanos de aridane
# Processing Record 7 of Set 15 | mnogovershinnyy
# Processing Record 8 of Set 15 | aklavik
# Processing Record 9 of Set 15 | regina
# Processing Record 10 of Set 15 | herat
# Processing Record 11 of Set 15 | awjilah
# Processing Record 12 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 13 of Set 15 | abalak
# Processing Record 14 of Set 15 | blyznyuky
# Processing Record 15 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 15 | mayor pablo lagerenza
# Processing Record 17 of Set 15 | mount pleasant
# Processing Record 18 of Set 15 | cururupu
# Processing Record 19 of Set 15 | kurumkan
# Processing Record 20 of Set 15 | malpe
# Processing Record 21 of Set 15 | nuevo progreso
# Processing Record 22 of Set 15 | catalao
# Processing Record 23 of Set 15 | aswan
# Processing Record 24 of Set 15 | itoman
# Processing Record 25 of Set 15 | kizukuri
# Processing Record 26 of Set 15 | tefe
# Processing Record 27 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 15 | cedral
# Processing Record 29 of Set 15 | hereford
# Processing Record 30 of Set 15 | volodarskiy
# Processing Record 31 of Set 15 | launceston
# Processing Record 32 of Set 15 | serenje
# Processing Record 33 of Set 15 | auki
# Processing Record 34 of Set 15 | churapcha
# Processing Record 35 of Set 15 | belyy yar
# Processing Record 36 of Set 15 | banjar
# Processing Record 37 of Set 15 | saratovskaya
# Processing Record 38 of Set 15 | samarai
# Processing Record 39 of Set 15 | ponta delgada
# Processing Record 40 of Set 15 | pitimbu
# Processing Record 41 of Set 15 | srandakan
# Processing Record 42 of Set 15 | port lincoln
# Processing Record 43 of Set 15 | magadi
# Processing Record 44 of Set 15 | kemijarvi
# Processing Record 45 of Set 15 | ugoofaaru
# Processing Record 46 of Set 15 | kohima
# Processing Record 47 of Set 15 | idlib
# Processing Record 48 of Set 15 | itarema
# Processing Record 49 of Set 15 | rajauri
# Processing Record 50 of Set 15 | ulagan
# Processing Record 1 of Set 16 | sabla
# Processing Record 2 of Set 16 | alcaniz
# Processing Record 3 of Set 16 | havre-saint-pierre
# Processing Record 4 of Set 16 | eldorado
# Processing Record 5 of Set 16 | taiobeiras
# Processing Record 6 of Set 16 | velikiy ustyug
# Processing Record 7 of Set 16 | pacific grove
# Processing Record 8 of Set 16 | dharchula
# Processing Record 9 of Set 16 | bethanien
# Processing Record 10 of Set 16 | burica
# City not found. Skipping...
# Processing Record 11 of Set 16 | athabasca
# Processing Record 12 of Set 16 | ardakan
# Processing Record 13 of Set 16 | vanavara
# Processing Record 14 of Set 16 | vila velha
# Processing Record 15 of Set 16 | bodh gaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 710

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saskylakh  71.9167  114.0833     -6.83        96         100
# 1         Namtsy  62.7161  129.6658    -20.85        99          13
# 2     Big Spring  32.2504 -101.4787     48.24        38           0
# 3   Punta Arenas -53.1500  -70.9167     60.91        36           0
# 4    Pangnirtung  66.1451  -65.7125     10.40        72         100
# 5  Leningradskiy  69.3833  178.4167     -6.05        98          99
# 6           Olga  43.7444  135.2892     25.07        85           5
# 7     Port Hardy  50.6996 -127.4199     41.18       100         100
# 8      Kavaratti  10.5669   72.6420     80.37        77         100
# 9        Camacha  33.0833  -16.3333     71.02        64          20
#
#    Wind Speed Country Current Description
# 0       10.63      RU     overcast clouds
# 1        4.74      RU          few clouds
# 2       19.57      US           clear sky
# 3       18.41      CL           clear sky
# 4        4.61      CA     overcast clouds
# 5        4.54      RU     overcast clouds
# 6        6.71      RU           clear sky
# 7        0.00      CA     overcast clouds
# 8        2.77      IN     overcast clouds
# 9        5.75      PT          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df= city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Saskylakh      RU  71.9167  114.0833     -6.83        96         100
# 1        Namtsy      RU  62.7161  129.6658    -20.85        99          13
# 2    Big Spring      US  32.2504 -101.4787     48.24        38           0
# 3  Punta Arenas      CL -53.1500  -70.9167     60.91        36           0
# 4   Pangnirtung      CA  66.1451  -65.7125     10.40        72         100
#
#    Wind Speed Current Description
# 0       10.63     overcast clouds
# 1        4.74          few clouds
# 2       19.57           clear sky
# 3       18.41           clear sky
# 4        4.61     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
